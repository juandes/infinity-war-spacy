# %% [markdown]
# # Reliving Avengers: Infinity War with spaCy and Natural Language Processing

# %% [markdown]
# ### Discovering the top nouns, verbs, entities and text similarity within the spoken lines of Earth’s Mightiest Heroes

# %% [markdown]
# After a long year of waiting, **Avengers: Endgame** is finally here. I, like you, and most of the world will be rushing to the cinemas on day one to catch the movie and experience how the Avengers save the world and end a ten years story. To calm down my nerves and ease the wait, I wanted to relive the previous movie, Infinity War, but differently and interactively. And, since I am a data guy, of course, it had to involve data and a couple of buzzwords.
#
# The answer? **Natural Language Processing**, or NLP for short.

# %% [markdown]
# Using spaCy, an NLP Python open source library designed to help us process and understand volumes of text, I analyzed the script of the movie to investigate the following concepts:
#
# - Overall top 10 verbs, nouns, adverbs and adjectives from the film.
# - Top verbs and nouns spoke by a particular character.
# - Top 30 named entities from the film.
# - The similarity between the spoken lines of each character pair, e.g., the similarity between Thor’s and Thanos’ lines.
#
# In this article, I will discuss and show my findings while explaining with code how I did it with spaCy.
#
# Aren’t you interested in code and technical words? Today is your lucky day! I want to say that the vocabulary and terms I’ll use here are mostly non-technical and user-friendly so even if you have no experience in NLP, AI, machine learning or *insert buzzword here*, you should be able to grasp the main idea and concepts I want to inform. So, feel free to ignore the pieces of code :)

# %% [markdown]
# ![the mad titan](https://cdn-images-1.medium.com/max/800/1*rjMOOgbiWstWp_XWox-T_A.jpeg)

# %% [markdown]
# ### Downloading the data

# %%
# !wget https://raw.githubusercontent.com/juandes/infinity-war-spacy/master/cleaned-script.txt
# !wget https://raw.githubusercontent.com/juandes/infinity-war-spacy/master/cleaned-script-subject.txt
# Out:
# --2019-05-01 08:11:26--  https://raw.githubusercontent.com/juandes/infinity-war-spacy/master/cleaned-script.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50384 (49K) [text/plain]
# Saving to: ‘cleaned-script.txt’
#
# cleaned-script.txt  100%[===================>]  49.20K  --.-KB/s    in 0.02s
#
# 2019-05-01 08:11:26 (2.41 MB/s) - ‘cleaned-script.txt’ saved [50384/50384]
#
# --2019-05-01 08:11:27--  https://raw.githubusercontent.com/juandes/infinity-war-spacy/master/cleaned-script-subject.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60572 (59K) [text/plain]
# Saving to: ‘cleaned-script-subject.txt’
#
# cleaned-script-subj 100%[===================>]  59.15K  --.-KB/s    in 0.02s
#
# 2019-05-01 08:11:27 (2.86 MB/s) - ‘cleaned-script-subject.txt’ saved [60572/60572]

# %% [markdown]
# ### Processing the data
# The data or text corpus — as is usually known in NLP — used for the experiment is the script of the movie, available at this [link](https://transcripts.fandom.com/wiki/Avengers:_Infinity_War). However, before using the data, I had to clean it up. Thus, I removed some unnecessary things such as the comments that describe an action, or scene e.g. *“[Thanos crushes the Tesseract, revealing the blue Space Stone…]”*, as well as the name of the character who says the line (actually, the name was used to know who said what, but not as part of the actual corpus used for the analysis). Moreover, as part of the spaCy data processing step, I’m ignoring the terms that are labeled as **stop words**, in other words, the commonly used words, e.g. “I”, “you”, “an”. Also, I’m using only the **lemma**, that’s it the canonical form, of each word. For instance, the verbs “talks,” “talked,” and “talking” are forms of the same lexeme, and its lemma is “talk”.

# %% [markdown]
# To process a piece of text in spaCy, first, we need to load our language model, followed by calling the model on a text corpus. The result is a ```Doc``` object, an object that holds the processed text.

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en_core_web_md==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz#egg=en_core_web_md==2.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.0.0/en_core_web_md-2.0.0.tar.gz (120.8MB)
#     100% |████████████████████████████████| 120.9MB 75.6MB/s
# Installing collected packages: en-core-web-md
#   Running setup.py install for en-core-web-md ... done
# Successfully installed en-core-web-md-2.0.0
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %%
import spacy
import re
import itertools
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np


# load a medium-sized language model
nlp = spacy.load("en_core_web_md")

with open('cleaned-script.txt', 'r') as file:
    text = file.read()
    
doc = nlp(text)

# %% [markdown]
# ### Top 10 verbs, nouns, adverbs and adjectives

# %%
def produce_plot(result, fig_name, kind):
    """Save plot of result
    Parameters:
    result: data to draw
    fig_name: figure name
    kind: type of data used to plot
    """
    
    plt.bar(["\"{}\"".format(i[0]) for i in result], [i[1] for i in result])
    plt.ylabel('total')
    plt.xlabel('term')
    plt.xticks(rotation=45, fontsize=12)
    plt.title("Top {}{} ({})".format(kind, 's', fig_name.title()))
    plt.subplots_adjust(bottom=0.30)
    plt.show()
    #plt.savefig("plots/{}_{}.png".format(fig_name.replace(" ", "_"), kind))
    plt.close()

# %%
def top_pos(doc, pos, n, fig_name=""):
    """Finds the top n spaCy pos

    Parameters:
    doc: spaCy's doc
    pos: pos we are interesting in finding; one of "VERB", "NOUN", "ADJ" or "ADV"
    n: how many pos
    fig_name: name of the plot
    """
    
    pos_count = {}
    for token in doc:
        # ignore stop words
        if token.is_stop:
            continue

        if token.pos_== pos:
            if token.lemma_ in pos_count:
                pos_count[token.lemma_] += 1
            else:
                pos_count[token.lemma_] = 1

    # sort by values, but before get only those keys where value > 1;
    # I want lemmas that appear more than one
    # lastly, get the first n results
    result = sorted({k: v for (k, v) in pos_count.items() if v > 1}.items(),
                    key=lambda kv: kv[1], reverse=True)[:n]

    print("top 10 {} {}".format(pos, result))
    produce_plot(result, fig_name, pos)

# %%
# %matplotlib inline
top_pos(doc, 'VERB', 10, "overall")
# Out:
# top 10 VERB [('be', 643), ('do', 175), ('have', 124), ('go', 93), ('get', 83), ('will', 65), ('know', 59), ('can', 47), ('come', 44), ('think', 38)]

# %%
# %matplotlib inline
top_pos(doc, 'NOUN', 10, "overall")
# Out:
# top 10 NOUN [('what', 100), ('stone', 26), ('life', 22), ('time', 21), ('way', 18), ('thing', 16), ('who', 16), ('guy', 15), ('something', 15), ('man', 14)]

# %%
# %matplotlib inline
top_pos(doc, 'ADJ', 10, "overall")
# Out:
# top 10 ADJ [('-PRON-', 182), ('good', 23), ('more', 16), ('right', 14), ('sorry', 13), ('little', 11), ('great', 9), ('sure', 9), ('all', 8), ('other', 8)]

# %%
# %matplotlib inline
top_pos(doc, 'ADV', 10, "overall")
# Out:
# top 10 ADV [('not', 203), ('so', 43), ('here', 40), ('there', 38), ('now', 33), ('where', 33), ('just', 25), ('how', 22), ('then', 21), ('too', 19)]

# %% [markdown]
# ### Top verbs and nouns mentioned by a particular character

# %%
def top_entities(doc, n, fig_name=""):
    """Finds the top n spaCy entities
    Parameters:
    doc: spaCy's doc
    n: how many entities
    fig_name: name of the plot
    """
    
    entities = {}
    # named entities
    for ent in doc.ents:
        # Print the entity text and its label
        if ent.text in entities:
            entities[ent.text] += 1
        else:
            entities[ent.text] = 1
    result = sorted(entities.items(), key=lambda kv: kv[1], reverse=True)[:n]
    print("top 10 entities {}".format(result))

    plt.bar(["\"{}\"".format(i[0]) for i in result], [i[1] for i in result])
    plt.ylabel('total')
    plt.xlabel('named entity')
    plt.xticks(rotation='vertical', fontsize=10)
    plt.title("Top {} named entities ({})".format(n, fig_name.title()))
    plt.subplots_adjust(bottom=0.40)
    plt.show()
    #plt.savefig("plots/{}_entity.png".format(fig_name.replace(" ", "_")))
    plt.close()

# %%
def character_results(nlp):
    """Creates a doc per character using their lines,
    and calculate the top 10 pos and entities
    Parameters:
    nlp: spaCy's nlp
    Returns:
    character:doc dict
   """
    # these are the characters I want to analyze
    subjects = ['thor', 'tony stark', 'bruce banner', 'doctor strange',
                'steve rogers', 'thanos', 'wanda maximoff', 'vision',
                'natasha romanoff', 'gamora', 'peter quill', 'ebony maw',
                'james rhodes', 'rocket', 'peter parker', 'groot', 'drax']
    # create a map of character:doc
    subjects_docs = {}

    for subject in subjects:
        print("Subject: {}".format(subject))
        with open('cleaned-script-subject.txt', 'r') as file:
            # this list will contain all the lines produced by the subject
            lines_with_subject = []
            for line in file:
                if line.lower().startswith(subject):
                    # remove the subject, e.g. Thanos :.... before appending
                    lines_with_subject.append(re.sub(r'.*:', '', line.lower()))
        # create a doc using a long string with line break between line
        # made from all the lines spoken by the subject
        doc = nlp('\n'.join(lines_with_subject))
        top_pos(doc, 'VERB', 10, subject)
        top_pos(doc, 'NOUN', 10, subject)
        top_pos(doc, 'ADJ', 10, subject)
        top_pos(doc, 'ADV', 10, subject)
        top_entities(doc, 10, subject)
        subjects_docs[subject] = doc

    return subjects_docs

# %%
subjects_docs = character_results(nlp)
# Out:
# Subject: thor
# top 10 VERB [('be', 53), ('do', 14), ('have', 13), ('go', 10), ('know', 7), ('kill', 7), ('will', 7), ('die', 4), ('can', 4), ('destroy', 3)]
# top 10 NOUN [('what', 8), ('stone', 7), ('thanos', 5), ('hammer', 4), ('rabbit', 4), ('pod', 3), ('power', 3), ('mind', 3), ('one', 3), ('asgard', 2)]
# top 10 ADJ [('-PRON-', 16), ('wrong', 3), ('dark', 3), ('half', 2), ('nivadellir', 2), ('good', 2), ('dead', 2), ('alive', 2), ('late', 2)]
# top 10 ADV [('not', 11), ('so', 6), ('there', 6), ('really', 3), ('how', 3), ('when', 3), ('only', 3), ('then', 2), ('round', 2), ('maybe', 2)]
# top 10 entities [('\n\n ', 50), ('\n\n  ', 10), ('…', 2), ('  ', 1), ('four-digit', 1), ('first', 1), ('years', 1), ('six', 1), ('last week', 1), ('half', 1)]
# Subject: tony stark
# top 10 VERB [('be', 104), ('do', 30), ('get', 21), ('have', 16), ('go', 13), ('know', 9), ('should', 6), ('say', 6), ('let', 6), ('hear', 6)]
# top 10 NOUN [('what', 17), ('kid', 7), ('thing', 5), ('who', 4), ('earth', 4), ('guy', 4), ('plan', 4), ('dream', 3), ('stone', 3), ('time', 3)]
# top 10 ADJ [('-PRON-', 28), ('good', 7), ('more', 4), ('sorry', 4), ('right', 3), ('real', 2), ('nice', 2), ('sure', 2), ('least', 2)]
# top 10 ADV [('not', 37), ('just', 10), ('so', 9), ('now', 8), ('here', 7), ('there', 6), ('really', 4), ('where', 3), ('right', 3), ('back', 3)]
# top 10 entities [('\n\n ', 77), ('\n\n  ', 28), ('one', 4), ('f.r.i.d.a.y', 3), ('last night', 1), ('tonight', 1), ('\n\n  bruce.', 1), ('six', 1), ("ben & jerry's", 1), ('two weeks ago', 1)]
# Subject: bruce banner
# top 10 VERB [('be', 37), ('come', 12), ('do', 10), ('have', 8), ('get', 8), ('go', 6), ('make', 4), ('know', 4), ('think', 4), ('take', 2)]
# top 10 NOUN [('hulk', 8), ('stone', 7), ('what', 6), ('vision', 5), ('man', 4), ('thing', 3), ('guy', 3), ('york', 2), ('universe', 2), ('hand', 2)]
# top 10 ADJ [('tony', 3), ('-PRON-', 3), ('big', 3), ('last', 3), ('new', 2), ('whole', 2), ('good', 2), ('okay', 2)]
# top 10 ADV [('not', 12), ('there', 5), ('now', 4), ('where', 4), ('already', 2), ('here', 2)]
# top 10 entities [('\n\n ', 32), ('\n\n  ', 8), ('half', 1), ('six', 1), ('last second', 1)]
# Subject: doctor strange
# top 10 VERB [('be', 19), ('do', 8), ('will', 8), ('can', 7), ('have', 4), ('want', 3), ('come', 3), ('protect', 3), ('may', 3), ('find', 3)]
# top 10 NOUN [('stone', 6), ('what', 5), ('time', 5), ('who', 3), ('life', 3), ('thanos', 3), ('congratulation', 2), ('way', 2), ('fate', 2), ('universe', 2)]
# top 10 ADJ [('-PRON-', 11), ('stark', 3), ('strange', 2)]
# top 10 ADV [('not', 12), ('seriously', 3), ('here', 3), ('then', 2), ('quite', 2), ('home', 2), ('now', 2)]
# top 10 entities [('\n\n ', 30), ('\n\n  ', 11), ('  ', 1), ('14,000,605', 1), ('trillions', 1)]
# Subject: steve rogers
# top 10 VERB [('be', 7), ('go', 5), ('get', 3), ('fight', 2), ("'d", 2)]
# top 10 NOUN [('vision', 2)]
# top 10 ADJ [('-PRON-', 4)]
# top 10 ADV [('not', 4), ('here', 2), ('too', 2), ('how', 2), ('where', 2)]
# top 10 entities [('\n\n ', 13), ('\n\n  ', 9), ('  ', 1), ('2600', 1), ('0-3-0', 1)]
# Subject: thanos
# top 10 VERB [('be', 58), ('have', 13), ('know', 11), ('do', 11), ('would', 6), ('should', 5), ('go', 4), ('find', 3), ('bring', 3), ('come', 3)]
# top 10 NOUN [('what', 8), ('stone', 8), ('time', 5), ('daughter', 5), ('child', 3), ('reality', 3), ('day', 3), ('will', 3), ('soul', 3), ('destiny', 2)]
# top 10 ADJ [('-PRON-', 20), ('little', 4), ('more', 3), ('only', 3), ('same', 2), ('much', 2), ('great', 2), ('hungry', 2), ('full', 2), ('finite', 2)]
# top 10 ADV [('so', 9), ('not', 8), ('now', 4), ('there', 4), ('too', 4), ('where', 4), ('why', 4), ('here', 3), ('even', 3), ('still', 3)]
# top 10 entities [('\n\n ', 54), ('\n\n  ', 12), ('one', 3), ('  ', 1), ('two', 1), ('earth', 1), ('almost twenty years', 1), ('this day', 1), ('six', 1), ('half', 1)]
# Subject: wanda maximoff
# top 10 VERB [('be', 17), ('get', 5), ('come', 4), ('do', 3), ('can', 3), ('say', 2), ('go', 2), ('have', 2), ('stay', 2)]
# top 10 NOUN [('what', 4), ('vision', 4), ('stone', 2)]
# top 10 ADJ [('-PRON-', 2)]
# top 10 ADV [('not', 6), ('just', 3), ('there', 2), ('too', 2)]
# top 10 entities [('\n\n ', 22), ('\n\n  ', 4), ('11', 1)]
# Subject: vision
# top 10 VERB [('be', 23), ('have', 7), ('do', 6), ('can', 6), ('know', 3), ('go', 3), ('could', 3), ('think', 3), ('stay', 3), ('destroy', 3)]
# top 10 NOUN [('what', 6), ('stone', 5), ('time', 3), ('captain', 3), ('life', 3), ('something', 2), ('train', 2), ('year', 2), ('way', 2), ('thanos', 2)]
# top 10 ADJ [('-PRON-', 7), ('right', 3), ('half', 2)]
# top 10 ADV [('not', 12), ('all', 3), ('just', 2)]
# top 10 entities [('\n\n ', 21), ('\n\n  ', 5), ('…', 2), ('half', 2), (' \n\n ', 1), ('two years', 1), ('one', 1), ('70 years ago', 1), ('how many millions', 1)]
# Subject: natasha romanoff
# top 10 VERB [('be', 5), ('do', 3), ('look', 3), ('have', 2), ('take', 2)]
# top 10 NOUN [('deal', 2), ('bruce', 2)]
# top 10 ADJ [('-PRON-', 3)]
# top 10 ADV [('not', 3), ('how', 2)]
# top 10 entities [('\n\n ', 12), ('bruce', 2), ('  ', 1), ('\n\n  ', 1), ('scott', 1)]
# Subject: gamora
# top 10 VERB [('be', 20), ('do', 13), ('go', 6), ('know', 6), ('kill', 4), ('stop', 4), ('would', 4), ('will', 4), ('get', 3), ('need', 3)]
# top 10 NOUN [('stone', 5), ('life', 4), ('planet', 4), ('universe', 3), ('massacre', 2), ('thanos', 2), ('…', 2), ('what', 2)]
# top 10 ADJ [('-PRON-', 8), ('which', 2), ('safe', 2)]
# top 10 ADV [('not', 10), ('now', 3), ('why', 2), ('too', 2), ('really', 2), ('always', 2), ('when', 2)]
# top 10 entities [('\n\n ', 34), ('\n\n  ', 6), ('…', 3), ('half', 2), ('  ', 1), ('six', 1), ('one', 1)]
# Subject: peter quill
# top 10 VERB [('be', 81), ('do', 26), ('go', 14), ('have', 9), ('tell', 7), ('let', 6), ('kill', 6), ('get', 5), ('think', 5), ('mean', 4)]
# top 10 NOUN [('what', 10), ('drax', 7), ('thanos', 4), ('place', 3), ('stone', 3), ('kind', 3), ('gamora', 3), ('plan', 3), ('face', 2), ('call', 2)]
# top 10 ADJ [('-PRON-', 21), ('little', 2), ('which', 2), ('hard', 2), ('what', 2), ('fine', 2), ('good', 2)]
# top 10 ADV [('not', 33), ('where', 8), ('right', 6), ('so', 4), ('here', 4), ('yet', 4), ('all', 3), ('how', 3), ('then', 3), ('really', 3)]
# top 10 entities [('\n\n ', 54), ('\n\n  ', 19), ('  ', 1), ('…', 1), ('first', 1), ('one', 1), ('three', 1), ('missouri', 1), ('eight degrees', 1), ('half', 1)]
# Subject: ebony maw
# top 10 VERB [('be', 15), ('have', 9), ('hear', 2), ('rejoice', 2), ('save', 2), ('die', 2), ('will', 2)]
# top 10 NOUN [('stone', 4), ('child', 3), ('thanos', 3), ('titan', 2), ('life', 2), ('power', 2), ('side', 2), ('time', 2)]
# top 10 ADJ [('-PRON-', 13), ('other', 2)]
# top 10 ADV [('not', 2), ('now', 2), ('only', 2)]
# top 10 entities [('\n\n ', 10), ('\n\n  ', 6), ('one', 2), ('two', 1), ('…', 1)]
# Subject: james rhodes
# top 10 VERB [('be', 15), ('have', 5), ('get', 4), ('go', 2), ('do', 2)]
# top 10 NOUN [('guy', 3), ('what', 3)]
# top 10 ADJ [('right', 2), ('-PRON-', 2)]
# top 10 ADV [('not', 4), ('back', 3), ('somewhere', 2)]
# top 10 entities [('\n\n ', 9), ('\n\n  ', 4), ('couple of years', 1), ('two', 1)]
# Subject: rocket
# top 10 VERB [('be', 42), ('get', 15), ('go', 9), ('do', 5), ('will', 5), ('come', 5), ('look', 4), ('say', 3), ('have', 3), ('could', 3)]
# top 10 NOUN [('what', 5), ('captain', 3), ('lot', 3), ('space', 3), ('wiper', 2), ('moron', 2), ('groot', 2), ('way', 2), ('twig', 2), ('contraxia', 2)]
# top 10 ADJ [('-PRON-', 7), ('much', 3), ('right', 2), ('cool', 2), ('good', 2)]
# top 10 ADV [('not', 6), ('there', 3), ('here', 3), ('why', 2), ('ever', 2), ('very', 2), ('so', 2), ('how', 2)]
# top 10 entities [('\n\n ', 38), ('\n\n  ', 6), ('one', 2), ('two', 2), ('  ', 1), ('second', 1), ('groot', 1), ('100', 1)]
# Subject: peter parker
# top 10 VERB [('be', 35), ('do', 12), ('go', 8), ('say', 5), ('come', 5), ('get', 5), ('wanna', 5), ('know', 4), ('turn', 4), ('save', 3)]
# top 10 NOUN [('what', 9), ('way', 4), ('magic', 4), ('man', 3), ('sense', 2), ('neighborhood', 2), ('spider', 2), ('movie', 2), ('alien', 2), ('name', 2)]
# top 10 ADJ [('stark', 4), ('-PRON-', 4), ('sorry', 3), ('cool', 2)]
# top 10 ADV [('not', 15), ('here', 3), ('so', 3), ('just', 2), ('kinda', 2), ('really', 2)]
# top 10 entities [('\n\n ', 30), ('\n\n  ', 8), ('  ', 1)]
# Subject: groot
# top 10 VERB [('be', 7)]
# top 10 NOUN []
# top 10 ADJ []
# top 10 ADV []
# top 10 entities [('\n\n  ', 6), ('  ', 1)]
# Subject: drax
# top 10 VERB [('be', 17), ('have', 4), ('do', 3), ('will', 2), ('take', 2)]
# top 10 NOUN [('man', 3), ('dude', 2), ('daughter', 2), ('movement', 2), ('death', 2)]
# top 10 ADJ [('-PRON-', 4), ('invisible', 2)]
# top 10 ADV [('so', 2)]
# top 10 entities [('\n\n ', 20), ('\n\n  ', 2), ('third', 1), ('one', 1)]

# %%
def docs_similarities(subjects_docs):
    # remove Groot from dict 
    del subjects_docs['groot']
    # create a square ndarray of len(subjects_docs) filled with 1's
    similarities_matrix = np.full((len(subjects_docs), len(subjects_docs)), fill_value=1.0)

    # for every possible combination pair
    # e.g. (Tony, Strange), (Tony, Rocket) and so on
    for a, b in itertools.product(enumerate(subjects_docs), repeat=2):
        similarity_score = subjects_docs[a[1]].similarity(subjects_docs[b[1]])
        print("Similarity between {} and {} docs is {}".format(a[1], b[1], similarity_score))
        similarities_matrix[a[0], b[0]] = similarity_score

    plt.matshow(similarities_matrix, interpolation='nearest')
    plt.yticks(range(len(subjects_docs)), subjects_docs.keys())
    plt.xticks(range(len(subjects_docs)), subjects_docs.keys(), rotation='vertical')
    plt.tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)
    plt.colorbar()
    plt.title("Character's Corpus Similarity Matrix")
    #plt.savefig("plots/similarity_matrix.png", bbox_inches='tight')
    plt.show()
    plt.close()

# %% [markdown]
# ### The similarity between the spoken lines of each character pair

# %%
docs_similarities(subjects_docs)
# Out:
# Similarity between thor and thor docs is 1.0
# Similarity between thor and tony stark docs is 0.9937895513726398
# Similarity between thor and bruce banner docs is 0.994496165465929
# Similarity between thor and doctor strange docs is 0.9934792136595321
# Similarity between thor and steve rogers docs is 0.9873623490477792
# Similarity between thor and thanos docs is 0.9965986336725233
# Similarity between thor and wanda maximoff docs is 0.9873662601150033
# Similarity between thor and vision docs is 0.9937780933223939
# Similarity between thor and natasha romanoff docs is 0.9909575213080908
# Similarity between thor and gamora docs is 0.9940187522680113
# Similarity between thor and peter quill docs is 0.9926865540973882
# Similarity between thor and ebony maw docs is 0.9873578555414395
# Similarity between thor and james rhodes docs is 0.9916402666134809
# Similarity between thor and rocket docs is 0.9919330372931638
# Similarity between thor and peter parker docs is 0.9784141210885672
# Similarity between thor and drax docs is 0.9902608824841892
# Similarity between tony stark and thor docs is 0.9937895513726398
# Similarity between tony stark and tony stark docs is 1.0
# Similarity between tony stark and bruce banner docs is 0.9964548178551124
# Similarity between tony stark and doctor strange docs is 0.9923498570204132
# Similarity between tony stark and steve rogers docs is 0.9943838207596227
# Similarity between tony stark and thanos docs is 0.9934454140449736
# Similarity between tony stark and wanda maximoff docs is 0.9933287649730873
# Similarity between tony stark and vision docs is 0.9935262965269887
# Similarity between tony stark and natasha romanoff docs is 0.9914716721853242
# Similarity between tony stark and gamora docs is 0.9946424339077786
# Similarity between tony stark and peter quill docs is 0.9982981722970461
# Similarity between tony stark and ebony maw docs is 0.9750568256170592
# Similarity between tony stark and james rhodes docs is 0.9960579055418703
# Similarity between tony stark and rocket docs is 0.9968636449746464
# Similarity between tony stark and peter parker docs is 0.9899514379820211
# Similarity between tony stark and drax docs is 0.987961046324897
# Similarity between bruce banner and thor docs is 0.994496165465929
# Similarity between bruce banner and tony stark docs is 0.9964548178551124
# Similarity between bruce banner and bruce banner docs is 1.0
# Similarity between bruce banner and doctor strange docs is 0.9899565515730171
# Similarity between bruce banner and steve rogers docs is 0.991228938350487
# Similarity between bruce banner and thanos docs is 0.9908127272722862
# Similarity between bruce banner and wanda maximoff docs is 0.9892053438548186
# Similarity between bruce banner and vision docs is 0.9898931264396865
# Similarity between bruce banner and natasha romanoff docs is 0.988271896263771
# Similarity between bruce banner and gamora docs is 0.991094551595092
# Similarity between bruce banner and peter quill docs is 0.9959884853190032
# Similarity between bruce banner and ebony maw docs is 0.9746221262951552
# Similarity between bruce banner and james rhodes docs is 0.9940457131194051
# Similarity between bruce banner and rocket docs is 0.9952716685646418
# Similarity between bruce banner and peter parker docs is 0.9895243628556736
# Similarity between bruce banner and drax docs is 0.9895607915241651
# Similarity between doctor strange and thor docs is 0.9934792136595321
# Similarity between doctor strange and tony stark docs is 0.9923498570204132
# Similarity between doctor strange and bruce banner docs is 0.9899565515730171
# Similarity between doctor strange and doctor strange docs is 1.0
# Similarity between doctor strange and steve rogers docs is 0.9882243688695963
# Similarity between doctor strange and thanos docs is 0.9959675026611364
# Similarity between doctor strange and wanda maximoff docs is 0.9903991560735321
# Similarity between doctor strange and vision docs is 0.9952087597883859
# Similarity between doctor strange and natasha romanoff docs is 0.9911018620774493
# Similarity between doctor strange and gamora docs is 0.99434600728921
# Similarity between doctor strange and peter quill docs is 0.9897191005309719
# Similarity between doctor strange and ebony maw docs is 0.9885843461043184
# Similarity between doctor strange and james rhodes docs is 0.9899776876141988
# Similarity between doctor strange and rocket docs is 0.9901697637493782
# Similarity between doctor strange and peter parker docs is 0.9746568905540021
# Similarity between doctor strange and drax docs is 0.9837931779126611
# Similarity between steve rogers and thor docs is 0.9873623490477792
# Similarity between steve rogers and tony stark docs is 0.9943838207596227
# Similarity between steve rogers and bruce banner docs is 0.991228938350487
# Similarity between steve rogers and doctor strange docs is 0.9882243688695963
# Similarity between steve rogers and steve rogers docs is 1.0
# Similarity between steve rogers and thanos docs is 0.9883467661397674
# Similarity between steve rogers and wanda maximoff docs is 0.9897106823125338
# Similarity between steve rogers and vision docs is 0.9894502490571252
# Similarity between steve rogers and natasha romanoff docs is 0.9857840282952159
# Similarity between steve rogers and gamora docs is 0.990176070131907
# Similarity between steve rogers and peter quill docs is 0.9923730070049813
# Similarity between steve rogers and ebony maw docs is 0.9697114721356829
# Similarity between steve rogers and james rhodes docs is 0.9905099834304064
# Similarity between steve rogers and rocket docs is 0.989318455091022
# Similarity between steve rogers and peter parker docs is 0.9867272576928238
# Similarity between steve rogers and drax docs is 0.9823418125608746
# Similarity between thanos and thor docs is 0.9965986336725233
# Similarity between thanos and tony stark docs is 0.9934454140449736
# Similarity between thanos and bruce banner docs is 0.9908127272722862
# Similarity between thanos and doctor strange docs is 0.9959675026611364
# Similarity between thanos and steve rogers docs is 0.9883467661397674
# Similarity between thanos and thanos docs is 1.0
# Similarity between thanos and wanda maximoff docs is 0.991068598571221
# Similarity between thanos and vision docs is 0.9966962554484177
# Similarity between thanos and natasha romanoff docs is 0.9915452217848364
# Similarity between thanos and gamora docs is 0.9950452550497527
# Similarity between thanos and peter quill docs is 0.991791186915858
# Similarity between thanos and ebony maw docs is 0.9894353256867128
# Similarity between thanos and james rhodes docs is 0.990634078087758
# Similarity between thanos and rocket docs is 0.9899965746578194
# Similarity between thanos and peter parker docs is 0.9760043031346812
# Similarity between thanos and drax docs is 0.9883702496368918
# Similarity between wanda maximoff and thor docs is 0.9873662601150033
# Similarity between wanda maximoff and tony stark docs is 0.9933287649730873
# Similarity between wanda maximoff and bruce banner docs is 0.9892053438548186
# Similarity between wanda maximoff and doctor strange docs is 0.9903991560735321
# Similarity between wanda maximoff and steve rogers docs is 0.9897106823125338
# Similarity between wanda maximoff and thanos docs is 0.991068598571221
# Similarity between wanda maximoff and wanda maximoff docs is 1.0
# Similarity between wanda maximoff and vision docs is 0.9916738615659964
# Similarity between wanda maximoff and natasha romanoff docs is 0.988377574594251
# Similarity between wanda maximoff and gamora docs is 0.9909994624997964
# Similarity between wanda maximoff and peter quill docs is 0.9918984072987211
# Similarity between wanda maximoff and ebony maw docs is 0.9723741084527763
# Similarity between wanda maximoff and james rhodes docs is 0.9905038611624386
# Similarity between wanda maximoff and rocket docs is 0.9903119501639445
# Similarity between wanda maximoff and peter parker docs is 0.980809321853134
# Similarity between wanda maximoff and drax docs is 0.9813665475397298
# Similarity between vision and thor docs is 0.9937780933223939
# Similarity between vision and tony stark docs is 0.9935262965269887
# Similarity between vision and bruce banner docs is 0.9898931264396865
# Similarity between vision and doctor strange docs is 0.9952087597883859
# Similarity between vision and steve rogers docs is 0.9894502490571252
# Similarity between vision and thanos docs is 0.9966962554484177
# Similarity between vision and wanda maximoff docs is 0.9916738615659964
# Similarity between vision and vision docs is 1.0
# Similarity between vision and natasha romanoff docs is 0.9914816051195279
# Similarity between vision and gamora docs is 0.9950845213820225
# Similarity between vision and peter quill docs is 0.9916203889072275
# Similarity between vision and ebony maw docs is 0.9837817649626149
# Similarity between vision and james rhodes docs is 0.9906066853010109
# Similarity between vision and rocket docs is 0.9884877388306443
# Similarity between vision and peter parker docs is 0.9774139456422131
# Similarity between vision and drax docs is 0.9826417060938172
# Similarity between natasha romanoff and thor docs is 0.9909575213080908
# Similarity between natasha romanoff and tony stark docs is 0.9914716721853242
# Similarity between natasha romanoff and bruce banner docs is 0.988271896263771
# Similarity between natasha romanoff and doctor strange docs is 0.9911018620774493
# Similarity between natasha romanoff and steve rogers docs is 0.9857840282952159
# Similarity between natasha romanoff and thanos docs is 0.9915452217848364
# Similarity between natasha romanoff and wanda maximoff docs is 0.988377574594251
# Similarity between natasha romanoff and vision docs is 0.9914816051195279
# Similarity between natasha romanoff and natasha romanoff docs is 1.0
# Similarity between natasha romanoff and gamora docs is 0.9892440946278667
# Similarity between natasha romanoff and peter quill docs is 0.988048933796467
# Similarity between natasha romanoff and ebony maw docs is 0.9782422011394214
# Similarity between natasha romanoff and james rhodes docs is 0.9904876678298414
# Similarity between natasha romanoff and rocket docs is 0.9883385480535969
# Similarity between natasha romanoff and peter parker docs is 0.9720278468989302
# Similarity between natasha romanoff and drax docs is 0.9775736214975066
# Similarity between gamora and thor docs is 0.9940187522680113
# Similarity between gamora and tony stark docs is 0.9946424339077786
# Similarity between gamora and bruce banner docs is 0.991094551595092
# Similarity between gamora and doctor strange docs is 0.99434600728921
# Similarity between gamora and steve rogers docs is 0.990176070131907
# Similarity between gamora and thanos docs is 0.9950452550497527
# Similarity between gamora and wanda maximoff docs is 0.9909994624997964
# Similarity between gamora and vision docs is 0.9950845213820225
# Similarity between gamora and natasha romanoff docs is 0.9892440946278667
# Similarity between gamora and gamora docs is 1.0
# Similarity between gamora and peter quill docs is 0.9941807139400972
# Similarity between gamora and ebony maw docs is 0.9814156052899203
# Similarity between gamora and james rhodes docs is 0.9897324034695371
# Similarity between gamora and rocket docs is 0.9917123017611142
# Similarity between gamora and peter parker docs is 0.9818080164349049
# Similarity between gamora and drax docs is 0.9845426204092976
# Similarity between peter quill and thor docs is 0.9926865540973882
# Similarity between peter quill and tony stark docs is 0.9982981722970461
# Similarity between peter quill and bruce banner docs is 0.9959884853190032
# Similarity between peter quill and doctor strange docs is 0.9897191005309719
# Similarity between peter quill and steve rogers docs is 0.9923730070049813
# Similarity between peter quill and thanos docs is 0.991791186915858
# Similarity between peter quill and wanda maximoff docs is 0.9918984072987211
# Similarity between peter quill and vision docs is 0.9916203889072275
# Similarity between peter quill and natasha romanoff docs is 0.988048933796467
# Similarity between peter quill and gamora docs is 0.9941807139400972
# Similarity between peter quill and peter quill docs is 1.0
# Similarity between peter quill and ebony maw docs is 0.971671380699159
# Similarity between peter quill and james rhodes docs is 0.9941476701999584
# Similarity between peter quill and rocket docs is 0.9965024900981119
# Similarity between peter quill and peter parker docs is 0.992581988340165
# Similarity between peter quill and drax docs is 0.9878347567391397
# Similarity between ebony maw and thor docs is 0.9873578555414395
# Similarity between ebony maw and tony stark docs is 0.9750568256170592
# Similarity between ebony maw and bruce banner docs is 0.9746221262951552
# Similarity between ebony maw and doctor strange docs is 0.9885843461043184
# Similarity between ebony maw and steve rogers docs is 0.9697114721356829
# Similarity between ebony maw and thanos docs is 0.9894353256867128
# Similarity between ebony maw and wanda maximoff docs is 0.9723741084527763
# Similarity between ebony maw and vision docs is 0.9837817649626149
# Similarity between ebony maw and natasha romanoff docs is 0.9782422011394214
# Similarity between ebony maw and gamora docs is 0.9814156052899203
# Similarity between ebony maw and peter quill docs is 0.971671380699159
# Similarity between ebony maw and ebony maw docs is 1.0
# Similarity between ebony maw and james rhodes docs is 0.9746476043129457
# Similarity between ebony maw and rocket docs is 0.974041629692332
# Similarity between ebony maw and peter parker docs is 0.9486120051042829
# Similarity between ebony maw and drax docs is 0.9770180250036684
# Similarity between james rhodes and thor docs is 0.9916402666134809
# Similarity between james rhodes and tony stark docs is 0.9960579055418703
# Similarity between james rhodes and bruce banner docs is 0.9940457131194051
# Similarity between james rhodes and doctor strange docs is 0.9899776876141988
# Similarity between james rhodes and steve rogers docs is 0.9905099834304064
# Similarity between james rhodes and thanos docs is 0.990634078087758
# Similarity between james rhodes and wanda maximoff docs is 0.9905038611624386
# Similarity between james rhodes and vision docs is 0.9906066853010109
# Similarity between james rhodes and natasha romanoff docs is 0.9904876678298414
# Similarity between james rhodes and gamora docs is 0.9897324034695371
# Similarity between james rhodes and peter quill docs is 0.9941476701999584
# Similarity between james rhodes and ebony maw docs is 0.9746476043129457
# Similarity between james rhodes and james rhodes docs is 1.0
# Similarity between james rhodes and rocket docs is 0.9949480168197942
# Similarity between james rhodes and peter parker docs is 0.9845276041391353
# Similarity between james rhodes and drax docs is 0.9817747214620333
# Similarity between rocket and thor docs is 0.9919330372931638
# Similarity between rocket and tony stark docs is 0.9968636449746464
# Similarity between rocket and bruce banner docs is 0.9952716685646418
# Similarity between rocket and doctor strange docs is 0.9901697637493782
# Similarity between rocket and steve rogers docs is 0.989318455091022
# Similarity between rocket and thanos docs is 0.9899965746578194
# Similarity between rocket and wanda maximoff docs is 0.9903119501639445
# Similarity between rocket and vision docs is 0.9884877388306443
# Similarity between rocket and natasha romanoff docs is 0.9883385480535969
# Similarity between rocket and gamora docs is 0.9917123017611142
# Similarity between rocket and peter quill docs is 0.9965024900981119
# Similarity between rocket and ebony maw docs is 0.974041629692332
# Similarity between rocket and james rhodes docs is 0.9949480168197942
# Similarity between rocket and rocket docs is 1.0
# Similarity between rocket and peter parker docs is 0.9885150699863685
# Similarity between rocket and drax docs is 0.9857520560813126
# Similarity between peter parker and thor docs is 0.9784141210885672
# Similarity between peter parker and tony stark docs is 0.9899514379820211
# Similarity between peter parker and bruce banner docs is 0.9895243628556736
# Similarity between peter parker and doctor strange docs is 0.9746568905540021
# Similarity between peter parker and steve rogers docs is 0.9867272576928238
# Similarity between peter parker and thanos docs is 0.9760043031346812
# Similarity between peter parker and wanda maximoff docs is 0.980809321853134
# Similarity between peter parker and vision docs is 0.9774139456422131
# Similarity between peter parker and natasha romanoff docs is 0.9720278468989302
# Similarity between peter parker and gamora docs is 0.9818080164349049
# Similarity between peter parker and peter quill docs is 0.992581988340165
# Similarity between peter parker and ebony maw docs is 0.9486120051042829
# Similarity between peter parker and james rhodes docs is 0.9845276041391353
# Similarity between peter parker and rocket docs is 0.9885150699863685
# Similarity between peter parker and peter parker docs is 1.0
# Similarity between peter parker and drax docs is 0.9779785808024084
# Similarity between drax and thor docs is 0.9902608824841892
# Similarity between drax and tony stark docs is 0.987961046324897
# Similarity between drax and bruce banner docs is 0.9895607915241651
# Similarity between drax and doctor strange docs is 0.9837931779126611
# Similarity between drax and steve rogers docs is 0.9823418125608746
# Similarity between drax and thanos docs is 0.9883702496368918
# Similarity between drax and wanda maximoff docs is 0.9813665475397298
# Similarity between drax and vision docs is 0.9826417060938172
# Similarity between drax and natasha romanoff docs is 0.9775736214975066
# Similarity between drax and gamora docs is 0.9845426204092976
# Similarity between drax and peter quill docs is 0.9878347567391397
# Similarity between drax and ebony maw docs is 0.9770180250036684
# Similarity between drax and james rhodes docs is 0.9817747214620333
# Similarity between drax and rocket docs is 0.9857520560813126
# Similarity between drax and peter parker docs is 0.9779785808024084
# Similarity between drax and drax docs is 1.0
